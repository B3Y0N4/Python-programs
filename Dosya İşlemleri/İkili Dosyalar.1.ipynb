# %% [markdown]
# # Binary (İkili) Dosyalar ve Metin Dosyaları

# %% [markdown]
# # "rb" Modu

# %%
pdf = open("istiklalmarsi.pdf", "rb")

# %%
veri = pdf.read()

# %%
veri
# Out:
# b'%PDF-1.4\r%\xe2\xe3\xcf\xd3\r\n6 0 obj<</H[956 190]/Linearized 1/E 65654/L 69585/N 1/O 9/T 69419>>\rendobj\r                       \r\nxref\r\n6 33\r\n0000000016 00000 n\r\n0000001146 00000 n\r\n0000000956 00000 n\r\n0000001222 00000 n\r\n0000001399 00000 n\r\n0000001527 00000 n\r\n0000001661 00000 n\r\n0000001941 00000 n\r\n0000002070 00000 n\r\n0000002766 00000 n\r\n0000002924 00000 n\r\n0000003790 00000 n\r\n0000004466 00000 n\r\n0000005165 00000 n\r\n0000005859 00000 n\r\n0000006568 00000 n\r\n0000007339 00000 n\r\n0000008001 00000 n\r\n0000008706 00000 n\r\n0000016739 00000 n\r\n0000016991 00000 n\r\n0000017183 00000 n\r\n0000017479 00000 n\r\n0000026372 00000 n\r\n0000026625 00000 n\r\n0000037031 00000 n\r\n0000037277 00000 n\r\n0000037472 00000 n\r\n0000037784 00000 n\r\n0000056103 00000 n\r\n0000056350 00000 n\r\n0000065331 00000 n\r\n0000065578 00000 n\r\ntrailer\r\n<</Size 39/Prev 69409/Root 7 0 R/Info 5 0 R/ID[<cdc2efb65cef66b103680a3091c2ed6d><62456923b006524081821cc19f
# ...

# %% [markdown]
# # Bayt Kavramı

# %%
txt = open("file.txt", "r+", encoding="utf-8")

# %%
txt.tell()
# Out:
# 0

# %%
txt.read(10)
# Out:
# 'SpaceX\nKoç'

# %%
pdf = open("istiklalmarsi.pdf", "rb")

# %%
pdf.read(10)
# Out:
# b'%PDF-1.4\r%'

# %% [markdown]
# # Farklı Dosya Türleri

# %%
jpg = open("kizkulesi.jpg", "rb")

# %%
jpg.read(10)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF'

# %%
gif = open("kizkulesi.gif", "rb")

# %%
gif.read(10)
# Out:
# b'GIF89a3\x02\xba\x00'
